# %%
import sys
import os

# 获取项目根目录
root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
if root_path not in sys.path:
    sys.path.append(root_path)
import pandas as pd
from src.factors import dual_ma_factor
from src.factors import generate_signal
from src.backtest import dual_ma_backtest

# 修改路径到你的 data 文件夹
df = pd.read_csv("../data/600519.SH.csv")

# 按日期排序
df = df.sort_values("trade_date").reset_index(drop=True)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 9
#       5 root_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
#       6 if root_path not in sys.path:
#       7     sys.path.append(root_path)
#       8 import pandas as pd
# ----> 9 from src.factors import dual_ma_factor
#      10 from src.factors import generate_signal
#      11 from src.backtest import dual_ma_backtest
#      12
#
# ImportError: cannot import name 'dual_ma_factor' from 'src.factors' (c:\Users\zhenz\Momentum-Factor-Research\src\factors.py)

# %%
from src.factors import dual_ma_factor

df = dual_ma_factor(df)
df.tail()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from src.factors import dual_ma_factor
#       2
#       3 df = dual_ma_factor(df)
#       4 df.tail()
#
# ModuleNotFoundError: No module named 'src'

# %%
from src.factors import generate_signal

df = generate_signal(df)
df[["trade_date", "close", "MA_short", "MA_long", "signal"]].tail(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.factors import generate_signal
#       2
#       3 df = generate_signal(df)
#       4 df[["trade_date", "close", "MA_short", "MA_long", "signal"]].tail(10)
#
# ModuleNotFoundError: No module named 'src'

# %%
from src.backtest import dual_ma_backtest

df, total, annual, sharpe, mdd = dual_ma_backtest(df)
print(f"Annual Return: {annual*100:.2f}%")
print(f"Sharpe Ratio: {sharpe:.3f}")
print(f"Max Drawdown: {mdd*100:.2f}%")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(df["trade_date"], df["cum_ret"], label="Dual MA Strategy")
plt.xlabel("Date")
plt.ylabel("Cumulative Return")
plt.title("Dual Moving Average Strategy")
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       2
#       3 plt.figure(figsize=(12,5))
# ----> 4 plt.plot(df["trade_date"], df["cum_ret"], label="Dual MA Strategy")
#       5 plt.xlabel("Date")
#       6 plt.ylabel("Cumulative Return")
#       7 plt.title("Dual Moving Average Strategy")
#
# NameError: name 'df' is not defined
