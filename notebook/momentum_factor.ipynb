# %%
import sys
import pandas as pd
from pathlib import Path

sys.path.append('..')
from src.backtest import MultiFactorBacktest

data_dir = Path('../data')
price_data = {}

for csv_file in data_dir.glob('*.csv'):
    code = csv_file.stem
    df = pd.read_csv(csv_file)
    
    # 改成你实际的列名：trade_date
    df['date'] = pd.to_datetime(df['trade_date'])
    df = df.sort_values('date')
    
    price_data[code] = df

print(f"成功加载了 {len(price_data)} 只股票的数据，例如：{list(price_data.keys())[:3]}")

bt = MultiFactorBacktest(
    price_data=price_data,
    start_date='2023-01-01',
    end_date='2024-12-31',
    top_n=2
)

result = bt.run_backtest()

print(f"策略总收益率: {result['total_return']:.2%}")
print(f"持有天数: {len(result['daily_returns'])}")
# Out:
# 成功加载了 10 只股票的数据，例如：['000001.SZ', '000333.SZ', '000858.SZ']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 30
#      26     end_date='2024-12-31',
#      27     top_n=2
#      28 )
#      29
# ---> 30 result = bt.run_backtest()
#      31
#      32 print(f"策略总收益率: {result['total_return']:.2%}")
#      33 print(f"持有天数: {len(result['daily_returns'])}")
#
# File c:\Users\zhenz\Momentum-Factor-Research\notebook\..\src\backtest.py:25, in MultiFactorBacktest.run_backtest(self, rebalance_freq)
#      23 # 2. 获取所有交易日
#      24 all_dates = sorted(combined['date'].unique())
# ---> 25 all_dates = [d for d in all_dates if self.start_date <= d <= self.end_date]
#      26 rebalance_dates = all_dates[::rebalance_freq]
#      28 portfolio_returns = []
#
# TypeError: '<=' not supported between instances of 'str' and 'Timestamp'
